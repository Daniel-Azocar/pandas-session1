# %%
import pandas as pd

# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd

# %% [markdown]
# # Fundamentos de Pandas

# %%
# Crear un dataframe de ejemplo con nombres, apellidos y edades
data = pd.DataFrame(
    {
        'nombre' : ['Juan', 'Ana', 'Pedro', 'Maria'],
        'apellido' : ['Perez', 'Gomez', 'Lopez', 'Martinez'],
        'edad' : [28, 34, 29, 42]
    }
)

# %%
data
# Out:
#   nombre  apellido  edad
# 0   Juan     Perez    28
# 1    Ana     Gomez    34
# 2  Pedro     Lopez    29
# 3  Maria  Martinez    42

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nombre    4 non-null      object
#  1   apellido  4 non-null      object
#  2   edad      4 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
data["nombre"]
# Out:
# 0     Juan
# 1      Ana
# 2    Pedro
# 3    Maria
# Name: nombre, dtype: object

# %%
data[['nombre','edad']]
# Out:
#   nombre  edad
# 0   Juan    28
# 1    Ana    34
# 2  Pedro    29
# 3  Maria    42

# %%
data['edad'].max()
# Out:
# np.int64(42)

# %%
data['apellido']
# Out:
# 0       Perez
# 1       Gomez
# 2       Lopez
# 3    Martinez
# Name: apellido, dtype: object

# %%
data["apellido"].str.upper()
# Out:
# 0       PEREZ
# 1       GOMEZ
# 2       LOPEZ
# 3    MARTINEZ
# Name: apellido, dtype: object

# %%
data[]
# Out:
#   Cell In[15], line 1
#     data[]
#          ^
# SyntaxError: invalid syntax

# %%
data['apellido']
# Out:
# 0       Perez
# 1       Gomez
# 2       Lopez
# 3    Martinez
# Name: apellido, dtype: object

# %%
# Copia del dataframe
data2 = data.copy()

# %%
data2
# Out:
#   nombre  apellido  edad
# 0   Juan     Perez    28
# 1    Ana     Gomez    34
# 2  Pedro     Lopez    29
# 3  Maria  Martinez    42

# %%
# Descripcion de los datos
data2.describe()
# Out:
#             edad
# count   4.000000
# mean   33.250000
# std     6.396614
# min    28.000000
# 25%    28.750000
# 50%    31.500000
# 75%    36.000000
# max    42.000000

# %% [markdown]
# ### Cargar datos de una archivo .csv

# %%
# Leer el Dataset de carpeta de proyecto disponible
df_titanic0 = pd.read_csv(titanic_dataset.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Leer el Dataset de carpeta de proyecto disponible
# ----> 2 df_titanic0 = pd.read_csv(titanic_dataset.csv)
#
# NameError: name 'titanic_dataset' is not defined

# %%
df_titanic0 = pd.read_csv('titanic_dataset.csv')

# %%
df_titanic0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_titanic0.shape
# Out:
# (891, 12)

# %%
# Cuantas filas por columna
df_titanic0.shape[0]
# Out:
# 891

# %%
# Cuantas columnas
df_titanic0.shape[1]
# Out:
# 12

# %%
df_titanic0.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_titanic0.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df_titanic0.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_titanic0.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df_titanic0.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_titanic0.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df_titanic0.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_titanic0.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_titanic0["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# ### Creacion de subconjuntos

# %%
# Copia del df_titanic
df_titanic2 = df_titanic0.copy()

# %%
# Renombrar columnas
df_titanic2.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Extraer edad y sexo
df_age_sex = df_titanic2[["Age", "Sex"]]

# %%
df_age_sex.head(3)
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female

# %%
df_age_sex.shape
# Out:
# (891, 2)

# %%
df_age_sex.describe
# Out:
# <bound method NDFrame.describe of       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]>

# %%
# Extraer los datos de los pasajeros mayores a 30 a#os
df_titanic2[df_titanic2["Age"] > 30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
[df_titanic2["Age"] > 30]
# Out:
# [0      False
#  1       True
#  2      False
#  3       True
#  4       True
#         ...
#  886    False
#  887    False
#  888    False
#  889    False
#  890     True
#  Name: Age, Length: 891, dtype: bool]

# %%
df_titanic2["Sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
# Cantidad de mujeres en el Titanic
df_titanic2[df_titanic2["Sex"] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Cantidad de mujeres mayores de 30 a#os
df_titanic2[(df_titanic2["Sex"] == 'female') & (df_titanic2["Age"] > 30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 18            19         0       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic2[(df_titanic2["Sex"] == 'female') & (df_titanic2["Age"] > 30)].shape[0]
# Out:
# 103

# %%
df_titanic2[df_titanic2["Sex"] == 'female'].shape[0]
# Out:
# 314

# %%
df_female30 = df_titanic2[(df_titanic2["Sex"] == 'female') & (df_titanic2["Age"] > 30)]

# %%
df_female30.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   103.000000  103.000000  103.000000  103.000000  103.000000
# mean    457.145631    0.805825    1.737864   41.893204    0.504854
# std     257.487194    0.397498    0.803926    8.528686    0.575203
# min       2.000000    0.000000    1.000000   30.500000    0.000000
# 25%     264.500000    1.000000    1.000000   35.000000    0.000000
# 50%     459.000000    1.000000    2.000000   40.000000    0.000000
# 75%     675.000000    1.000000    2.000000   48.000000    1.000000
# max     886.000000    1.000000    3.000000   63.000000    3.000000
#
#             Parch        Fare
# count  103.000000  103.000000
# mean     0.708738   61.347290
# std      1.288190   70.120968
# min      0.000000    7.750000
# 25%      0.000000   16.700000
# 50%      0.000000   31.387500
# 75%      1.000000   79.825000
# max      6.000000  512.329200

# %%
df_female30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103 entries, 1 to 885
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  103 non-null    int64
#  1   Survived     103 non-null    int64
#  2   Pclass       103 non-null    int64
#  3   Name         103 non-null    object
#  4   Sex          103 non-null    object
#  5   Age          103 non-null    float64
#  6   SibSp        103 non-null    int64
#  7   Parch        103 non-null    int64
#  8   Ticket       103 non-null    object
#  9   Fare         103 non-null    float64
#  10  Cabin        49 non-null     object
#  11  Embarked     101 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 10.5+ KB

# %%
df_titanic2[df_titanic2["Sex"] == "female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_female = df_titanic2[df_titanic2["Sex"] == "female"]

# %%
df_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 314 entries, 1 to 888
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  314 non-null    int64
#  1   Survived     314 non-null    int64
#  2   Pclass       314 non-null    int64
#  3   Name         314 non-null    object
#  4   Sex          314 non-null    object
#  5   Age          261 non-null    float64
#  6   SibSp        314 non-null    int64
#  7   Parch        314 non-null    int64
#  8   Ticket       314 non-null    object
#  9   Fare         314 non-null    float64
#  10  Cabin        97 non-null     object
#  11  Embarked     312 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 31.9+ KB

# %%
# Cantidad de mujeres sin datos de edad
df_titanic2[df_titanic2["Age"].isnull() & (df_titanic2["Sex"] == "female")].shape[0]
# Out:
# 53

# %%
df_female_age_null = df_titanic2[df_titanic2["Age"].isnull() & (df_titanic2["Sex"] == "female")].shape[0]

# %%
df_female_age_null.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df_female_age_null.info()
#
# AttributeError: 'int' object has no attribute 'info'

# %%
df_female_age_null.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df_female_age_null.info()
#
# AttributeError: 'int' object has no attribute 'info'

# %%
df_female_age_null.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df_female_age_null.describe()
#
# AttributeError: 'int' object has no attribute 'describe'

# %%
df_female30[df_female30['Age'].notna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 18            19         0       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic2[df_titanic2['Age'].notna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Agregar columnas nuevas

# %%
df_titanic2["Meses"] = [df_titanic2["Age"]* 12]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df_titanic2["Meses"] = [df_titanic2["Age"]* 12]
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)   4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
# ...

# %%
df_titanic3["Meses"] = df_titanic2[["Age"] * 12]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df_titanic3["Meses"] = df_titanic2[["Age"] * 12]
#
# NameError: name 'df_titanic3' is not defined

# %%
# Agregar una nueva columna con la edad de los pasajeros en meses
df_titanic2["Meses"] = df_titanic2["Age"] * 12

# %%
df_titanic2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Meses
# 0      0         A/5 21171   7.2500   NaN        S  264.0
# 1      0          PC 17599  71.2833   C85        C  456.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  312.0
# 3      0            113803  53.1000  C123        S  420.0
# ...

# %%
# Para solo calcular una columna por x valor sin incluir en el dataframe
df_titanic2["Age"] * 12
# Out:
# 0      264.0
# 1      456.0
# 2      312.0
# 3      420.0
# 4      420.0
#        ...
# 886    324.0
# 887    228.0
# 888      NaN
# 889    312.0
# 890    384.0
# Name: Age, Length: 891, dtype: float64

# %%
# Para reordenar las columnas del dataframe
print(df_titanic2.columns.to_list())
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Meses']

# %%
new_order_column = ['Age','Sex' ,'PassengerId', 'Survived', 'Pclass', 'Name',  'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Meses']

# %%
df_titanic2 = df_titanic2[new_order_column]

# %%
df_titanic2.head()
# Out:
#     Age     Sex  PassengerId  Survived  Pclass  \
# 0  22.0    male            1         0       3
# 1  38.0  female            2         1       1
# 2  26.0  female            3         1       3
# 3  35.0  female            4         1       1
# 4  35.0    male            5         0       3
#
#                                                 Name  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
# 2                             Heikkinen, Miss. Laina      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# 4                           Allen, Mr. William Henry      0      0
#
#              Ticket     Fare Cabin Embarked  Meses
# 0         A/5 21171   7.2500   NaN        S  264.0
# 1          PC 17599  71.2833   C85        C  456.0
# 2  STON/O2. 3101282   7.9250   NaN        S  312.0
# 3            113803  53.1000  C123        S  420.0
# ...

# %% [markdown]
# ## Estadisticos por atributo

# %%
df_titanic2[df_titanic2["Embarked"]].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 df_titanic2[df_titanic2["Embarked"]].nunique()
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
# ...

# %%
df_titanic2["Embarked"].nunique()
# Out:
# 3

# %%
df_titanic2["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df_titanic2["Age"].median()
# Out:
# np.float64(28.0)

# %%
# Uso del  Groupby
df_age_sex.groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645
